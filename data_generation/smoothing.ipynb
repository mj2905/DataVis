# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import math
from math import floor
import imageio
import json
import pickle as pkl
import os

# %% [markdown]
# ## Load place

# %%
with pd.HDFStore("place.hdf", mode="r") as store:
    print(store.keys())
    place = store.place
    users = store.users
# Out:
# ['/place', '/users']

# %%
place.describe()
# Out:
#                  ts       user_id  x_coordinate  y_coordinate         color
# count  1.655990e+07  1.655990e+07  1.655990e+07  1.655990e+07  1.655990e+07
# mean   2.139252e+05  2.314466e+05  4.730365e+02  5.154545e+02  5.733436e+00
# std    6.689361e+04  2.229644e+05  2.882131e+02  2.996301e+02  4.437919e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.684950e+05  6.805400e+04  2.290000e+02  2.610000e+02  3.000000e+00
# 50%    2.249860e+05  1.619120e+05  4.590000e+02  5.080000e+02  5.000000e+00
# 75%    2.657800e+05  3.268200e+05  7.120000e+02  7.870000e+02  9.000000e+00
# max    3.200460e+05  1.166923e+06  1.000000e+03  1.000000e+03  1.500000e+01

# %%
place = place[place.ts>=60845]
place.ts = place.ts - 60845

# %% [markdown]
# ## Smoothing functions

# %%
def get_edits(place, _from, _to):
    canevas = place[(place.ts>=_from)&(place.ts<_to)]
    counts = canevas.shape[0]
    if counts == 0:
        return np.zeros((1000, 1000), dtype=np.float32), 0
    
    canevas = canevas.pivot_table(values="ts", index="y_coordinate", columns="x_coordinate", aggfunc=lambda x: len(x))
    canevas = canevas.reindex(index=np.arange(1001), columns=np.arange(1001))
    canevas_matrix = canevas.fillna(0).values[:-1, :-1]
    return canevas_matrix.astype(np.float32), counts

# %%
def get_gaussian_kernel(kernel_size=3, sigma=2, channels=1):
    # Create a x, y coordinate grid of shape (kernel_size, kernel_size, 2)
    x_coord = torch.arange(kernel_size)
    x_grid = x_coord.repeat(kernel_size).view(kernel_size, kernel_size)
    y_grid = x_grid.t()
    xy_grid = torch.stack([x_grid, y_grid], dim=-1).float()

    mean = (kernel_size - 1)/2.
    variance = sigma**2.

    # Calculate the 2-dimensional gaussian kernel which is
    # the product of two gaussian distributions for two different
    # variables (in this case called x and y)
    gaussian_kernel = (1./(2.*math.pi*variance)) *\
                      torch.exp(
                          -torch.sum((xy_grid - mean)**2., dim=-1) /\
                          (2*variance)
                      )

    # Make sure sum of values in gaussian kernel equals 1.
    gaussian_kernel = gaussian_kernel / torch.sum(gaussian_kernel)

    # Reshape to 2d depthwise convolutional weight
    gaussian_kernel = gaussian_kernel.view(1, 1, kernel_size, kernel_size)
    gaussian_kernel = gaussian_kernel.repeat(channels, 1, 1, 1)

    gaussian_filter = nn.Conv2d(in_channels=channels, out_channels=channels,
                                kernel_size=kernel_size, groups=channels, bias=False)

    gaussian_filter.weight.data = gaussian_kernel
    gaussian_filter.weight.requires_grad = False
    
    return gaussian_filter

# %%
def create_canevas_tensors(place, windows_start, window_size=15*60):
    tss = []
    edits_counts = []
    batch = []
    for ts in windows_start: #range(place.ts.min(), place.ts.max()+w_size, w_size):
        tss.append(ts)
        canevas, counts = get_edits(place, ts, ts+w_size)
        #print(canevas.max())
        edits_counts.append(counts)
        batch.append(canevas)
    tensor_batch = torch.cat([torch.Tensor(m).unsqueeze(0) for m in batch])
    tensor_batch.unsqueeze_(1)
    return tss, edits_counts, tensor_batch

# %%
class Smoother():
    def __init__(self, kernel, sigma, max_pool, cuda=1):
        self.cuda = cuda
        self.kernel = nn.Sequential(
            nn.AvgPool2d(max_pool, max_pool),
            nn.ReflectionPad2d((kernel-1)//2),
            get_gaussian_kernel(kernel, sigma, 1))
        if cuda != None:
            self.kernel = self.kernel.cuda(cuda)
        
    def __call__(self, image_tensor):
        if self.cuda is not None:
            image_tensor = image_tensor.cuda(self.cuda)
        smoothed = self.kernel(image_tensor)
        maxs, _ = smoothed.view(smoothed.size(0), -1).max(-1)
        return smoothed.cpu().numpy().squeeze(1), maxs.cpu().numpy().squeeze()

# %%
def generate_levelmaps(place, smoother, ts_window, community_id=None, users_id=None, root_path="data/levelmaps"):
    windows_start = range(place.ts.min(), place.ts.max()+1, w_size)
    
    if community_id is not None:
        place = place[place.user_id.isin(users_id)]
        print(f"Community {community_id}" + "-"*10)
    tss, edits_counts, canevas_tensor = create_canevas_tensors(place, windows_start, ts_window)
    smoothed, maxs = smoother(canevas_tensor)
    
    print("Tiles generated and smoothed, saving images")
    path = f"{root_path}/{'global' if community_id is None else community_id}"
    os.makedirs(path, exist_ok=True)
    
    for i in range(len(tss)):
        imageio.imwrite(f"{path}/{i}.png", (255*smoothed[i]/max(1,smoothed[i].max())).astype(np.uint8), optimize=True)

    index = {tss[i]: {"idx":i, "max":round(float(maxs[i]),5), "counts":edits_counts[i]} for i in range(len(tss))}
    
    with open(f"{path}/index.json", "w") as f:
        json.dump({community_id: index}, f)
        print(f"Images saved to {path}")
    return index

# %% [markdown]
# ## Apply smoothing

# %%
root_path = "levelmaps"
w_size = 30*60
kernel_size = 3
sigma = 1
strides = 5

smoother = Smoother(kernel_size, sigma, strides, cuda=1)

# %% [markdown]
# ## Apply smoothing on biggest "communities"

# %%
n_biggest_communities = 150

# %%
# see place_pixels.ipynb
with open("communities.pkl", mode="rb") as f:
    communities = pkl.load(f)

# %%
index = {}

index["global"] = generate_levelmaps(place, smoother, w_size, None, None, root_path)

for k in sorted(communities, key=lambda x: len(communities.get(x)), reverse=True)[:n_biggest_communities+1]:
    index[k] = generate_levelmaps(place, smoother, w_size, k, communities[k], root_path)
    
with open(f"{root_path}/index.json", "w") as f:
    json.dump(index, f)
# Out:
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/global
# Community 286----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/286
# Community 1122----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1122
# Community 75----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/75
# Community 1066----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1066
# Community 95----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/95
# Community 56----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/56
# Community 581----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/581
# Community 73----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/73
# Community 61----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/61
# Community 1692----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1692
# Community 46----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/46
# Community 360----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/360
# Community 21----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/21
# Community 235----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/235
# Community 2----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/2
# Community 1915----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1915
# Community 123----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/123
# Community 1628----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1628
# Community 12----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/12
# Community 19----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/19
# Community 57----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/57
# Community 299----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/299
# Community 1757----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1757
# Community 24----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/24
# Community 0----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/0
# Community 357----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/357
# Community 704----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/704
# Community 1139----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1139
# Community 1695----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1695
# Community 1509----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1509
# Community 147----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/147
# Community 214----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/214
# Community 59----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/59
# Community 33----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/33
# Community 4----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/4
# Community 23----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/23
# Community 1791----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1791
# Community 48----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/48
# Community 20----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/20
# Community 165----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/165
# Community 281----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/281
# Community 637----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/637
# Community 83----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/83
# Community 28----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/28
# Community 411----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/411
# Community 1847----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1847
# Community 268----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/268
# Community 179----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/179
# Community 110----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/110
# Community 955----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/955
# Community 378----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/378
# Community 390----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/390
# Community 129----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/129
# Community 80----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/80
# Community 199----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/199
# Community 135----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/135
# Community 871----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/871
# Community 397----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/397
# Community 25----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/25
# Community 1100----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1100
# Community 1289----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1289
# Community 13----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/13
# Community 88----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/88
# Community 1740----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1740
# Community 1262----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1262
# Community 757----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/757
# Community 301----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/301
# Community 71----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/71
# Community 484----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/484
# Community 122----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/122
# Community 81----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/81
# Community 1928----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1928
# Community 130----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/130
# Community 1102----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1102
# Community 30----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/30
# Community 27----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/27
# Community 1329----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1329
# Community 422----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/422
# Community 308----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/308
# Community 320----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/320
# Community 628----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/628
# Community 277----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/277
# Community 41----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/41
# Community 631----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/631
# Community 133----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/133
# Community 672----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/672
# Community 1097----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1097
# Community 231----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/231
# Community 139----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/139
# Community 1155----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1155
# Community 329----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/329
# Community 1832----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1832
# Community 684----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/684
# Community 892----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/892
# Community 206----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/206
# Community 302----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/302
# Community 74----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/74
# Community 236----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/236
# Community 96----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/96
# Community 453----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/453
# Community 1024----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1024
# Community 285----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/285
# Community 349----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/349
# Community 250----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/250
# Community 474----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/474
# Community 102----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/102
# Community 125----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/125
# Community 39----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/39
# Community 686----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/686
# Community 1050----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1050
# Community 1246----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1246
# Community 1----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1
# Community 288----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/288
# Community 467----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/467
# Community 90----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/90
# Community 382----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/382
# Community 1362----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1362
# Community 11----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/11
# Community 1543----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1543
# Community 69----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/69
# Community 387----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/387
# Community 210----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/210
# Community 426----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/426
# Community 175----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/175
# Community 55----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/55
# Community 350----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/350
# Community 380----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/380
# Community 442----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/442
# Community 15----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/15
# Community 126----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/126
# Community 652----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/652
# Community 145----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/145
# Community 146----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/146
# Community 1302----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1302
# Community 416----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/416
# Community 1018----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1018
# Community 1180----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1180
# Community 43----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/43
# Community 128----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/128
# Community 29----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/29
# Community 629----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/629
# Community 317----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/317
# Community 136----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/136
# Community 269----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/269
# Community 154----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/154
# Community 665----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/665
# Community 1926----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1926
# Community 1131----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/1131
# Community 229----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/229
# Community 53----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/53
# Community 49----------
# Tiles generated and smoothed, saving images
# Images saved to levelmaps/49
